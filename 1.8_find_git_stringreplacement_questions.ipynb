# %% [markdown]
# # find
#
# Syntax to find all .txt files in a directory,
#
# ```
# find ./<dir-name> -name "*.txt"
# ```
#
# Syntax to execute a command on all the files that match a pattern.
#
# ```
# find ./<dir-name> -name "*.txt" -exec bash -c 'wc -l $1' _ {} \;
# ```
#
# # Git
#
# Git Commands,
#
# ```
# cd test-repo/
# git init # Start a git repository
# git add . # Adds files into the git index
# git commit -m "Message here" # Takes a snapshot of the index
# git push <remote-url> master # Pushed commits to a remote repository
# git pull # Pulls from a remote repository
# ```
#
# # String Replacement
#
# Command to replace pattern in string,
#
# ```
# a="helloworld"
# a=${a/world/hello}
# echo $a
# ```
#
# # FASTQs
#
# Command to extract all read names from FASTQ files,
#
# ```
# awk 'NR%4==1' data/tmp/simulated1.R1.fq
# ```
#
# ## Questions
#
# 1. Count number of lines in each .txt files in ./data/tmp/ folder.
# 2. Create a local `git` repository on your account. Add atleast two files and make a commit.
# 3. Push these changes to a remote repository and add the url here.
# 4. Print all nucleotide sequences from data/tmp/simulate1.R1.fq
#
# ## HW
#
# 1. Count number of characters in the filename of each .txt file in ./data/tmp/ folder.
# 3. Print all nucleotide sequences from ./data/fastq/simulated1.R1.fq by replacing all 'T's in the nucleotide sequences with 'U's. Hint: ${variable//123/112} will replace all occurences of 123 with 112.

# %%
# %%bash
# cd
# cd Applied-Bioinformatics/Module-1_bash-jupyter-git/data/tmp
# for i in $(find ./ -name "*.txt")
# do
# wc -l $i
# done
# Out:
#        0 .//file1.txt
#        0 .//file10.txt
#        0 .//file100.txt
#        0 .//file101.txt
#        0 .//file102.txt
#        0 .//file103.txt
#        0 .//file104.txt
#        0 .//file105.txt
#        0 .//file106.txt
#        0 .//file107.txt
#        0 .//file108.txt
#        0 .//file109.txt
#        0 .//file11.txt
#        0 .//file110.txt
#        0 .//file111.txt
#        0 .//file114.txt
#        0 .//file115.txt
#        0 .//file116.txt
#        0 .//file117.txt
#        0 .//file118.txt
#        0 .//file119.txt
#        0 .//file12.txt
#        0 .//file120.txt
#        0 .//file121.txt
#        0 .//file122.txt
#        0 .//file123.txt
#        0 .//file124.txt
#        0 .//file125.txt
#        0 .//file126.txt
#        0 .//file127.txt
#        0 .//file128.txt
#        0 .//file129.txt
#        0 .//file13.txt
#        0 .//file130.txt
#        0 .//file131.txt
#        0 .//file132.txt
#        0 .//file133.txt
#        0 .//file134.txt
#        0 .//file135.txt
#        0 .//file136.txt
#        0 .//file138.txt
#        0 .//file139.txt
#        0 .//file14.txt
#        0 .//file140.txt
#        0 .//file141.txt
#        0 .//file142.txt
#        0 .//file143.txt
#        0 .//file144.txt
#        0 .//file145.txt
#        0 .//file146.txt
#        0 .//file147.txt
#        0 .//file148.txt
#        0 .//file149.txt
#        0 .//file15.txt
#        0 .//file150.txt
#        0 .//file151.txt
#        0 .//file152.txt
#        0 .//file153.txt
#        0 .//file154.txt
#        0 .//file155.txt
#        0 .//file156.txt
#        0 .//file157.txt
#        0 .//file158.txt
#        0 .//file159.txt
#        0 .//file16.txt
#        0 .//file160.txt
#        0 .//file161.txt
#        0 .//file162.txt
#        0 .//file163.txt
#        0 .//file164.txt
#        0 .//file165.txt
#        0 .//file166.txt
#        0 .//file167.txt
#        0 .//file168.txt
#        0 .//file169.txt
#        0 .//file17.txt
#        0 .//file170.txt
#        0 .//file171.txt
#        0 .//file172.txt
#        0 .//file173.txt
#        0 .//file174.txt
#        0 .//file175.txt
#        0 .//file176.txt
#        0 .//file177.txt
#        0 .//file178.txt
#        0 .//file179.txt
#        0 .//file18.txt
#        0 .//file180.txt
#        0 .//file181.txt
#        0 .//file182.txt
#        0 .//file183.txt
#        0 .//file184.txt
#        0 .//file185.txt
#        0 .//file186.txt
#        0 .//file187.txt
#        0 .//file188.txt
#        0 .//file189.txt
#        0 .//file19.txt
#        0 .//file190.txt
#        0 .//file191.txt
#        0 .//file192.txt
#        0 .//file193.txt
#        0 .//file194.txt
#        0 .//file195.txt
#        0 .//file196.txt
#        0 .//file197.txt
#        0 .//file198.txt
#        0 .//file199.txt
#        0 .//file2.txt
#        0 .//file200.txt
#        0 .//file21.txt
#        0 .//file22.txt
#        0 .//file23.txt
#        0 .//file24.txt
#        0 .//file25.txt
#        0 .//file26.txt
#        0 .//file27.txt
#        0 .//file28.txt
#        0 .//file29.txt
#        0 .//file3.txt
#        0 .//file30.txt
#        0 .//file31.txt
#        0 .//file32.txt
#        0 .//file33.txt
#        0 .//file34.txt
#        0 .//file35.txt
#        0 .//file36.txt
#        0 .//file38.txt
#        0 .//file39.txt
#        0 .//file4.txt
#        0 .//file40.txt
#        0 .//file41.txt
#        0 .//file42.txt
#        0 .//file44.txt
#        0 .//file45.txt
#        0 .//file46.txt
#        0 .//file47.txt
#        0 .//file48.txt
#        0 .//file49.txt
#        0 .//file5.txt
#        0 .//file50.txt
#        0 .//file51.txt
#        0 .//file52.txt
#        0 .//file53.txt
#        0 .//file54.txt
#        0 .//file55.txt
#        0 .//file56.txt
#        0 .//file57.txt
#        0 .//file58.txt
#        0 .//file59.txt
#        0 .//file6.txt
#        0 .//file60.txt
#        0 .//file61.txt
#        0 .//file62.txt
#        0 .//file64.txt
#        0 .//file65.txt
#        0 .//file66.txt
#        0 .//file67.txt
#        0 .//file68.txt
#        0 .//file69.txt
#        0 .//file7.txt
#        0 .//file70.txt
#        0 .//file71.txt
#        0 .//file72.txt
#        0 .//file73.txt
#        0 .//file74.txt
#        0 .//file75.txt
#        0 .//file76.txt
#        0 .//file77.txt
#        0 .//file78.txt
#        0 .//file79.txt
#        0 .//file8.txt
#        0 .//file80.txt
#        0 .//file81.txt
#        0 .//file82.txt
#        0 .//file84.txt
#        0 .//file85.txt
#        0 .//file86.txt
#        0 .//file87.txt
#        0 .//file88.txt
#        0 .//file89.txt
#        0 .//file9.txt
#        0 .//file90.txt
#        0 .//file91.txt
#        0 .//file92.txt
#        0 .//file93.txt
#        0 .//file94.txt
#        0 .//file96.txt
#        0 .//file97.txt
#        0 .//file98.txt
#        0 .//file99.txt

# %%
# %%bash
# cd
# cd Applied-Bioinformatics/Module-1_bash-jupyter-git/data/tmp
# find ./ -name "*.txt" -exec wc -l {} \;
# Out:
#        0 .//file1.txt
#        0 .//file10.txt
#        0 .//file100.txt
#        0 .//file101.txt
#        0 .//file102.txt
#        0 .//file103.txt
#        0 .//file104.txt
#        0 .//file105.txt
#        0 .//file106.txt
#        0 .//file107.txt
#        0 .//file108.txt
#        0 .//file109.txt
#        0 .//file11.txt
#        0 .//file110.txt
#        0 .//file111.txt
#        0 .//file114.txt
#        0 .//file115.txt
#        0 .//file116.txt
#        0 .//file117.txt
#        0 .//file118.txt
#        0 .//file119.txt
#        0 .//file12.txt
#        0 .//file120.txt
#        0 .//file121.txt
#        0 .//file122.txt
#        0 .//file123.txt
#        0 .//file124.txt
#        0 .//file125.txt
#        0 .//file126.txt
#        0 .//file127.txt
#        0 .//file128.txt
#        0 .//file129.txt
#        0 .//file13.txt
#        0 .//file130.txt
#        0 .//file131.txt
#        0 .//file132.txt
#        0 .//file133.txt
#        0 .//file134.txt
#        0 .//file135.txt
#        0 .//file136.txt
#        0 .//file138.txt
#        0 .//file139.txt
#        0 .//file14.txt
#        0 .//file140.txt
#        0 .//file141.txt
#        0 .//file142.txt
#        0 .//file143.txt
#        0 .//file144.txt
#        0 .//file145.txt
#        0 .//file146.txt
#        0 .//file147.txt
#        0 .//file148.txt
#        0 .//file149.txt
#        0 .//file15.txt
#        0 .//file150.txt
#        0 .//file151.txt
#        0 .//file152.txt
#        0 .//file153.txt
#        0 .//file154.txt
#        0 .//file155.txt
#        0 .//file156.txt
#        0 .//file157.txt
#        0 .//file158.txt
#        0 .//file159.txt
#        0 .//file16.txt
#        0 .//file160.txt
#        0 .//file161.txt
#        0 .//file162.txt
#        0 .//file163.txt
#        0 .//file164.txt
#        0 .//file165.txt
#        0 .//file166.txt
#        0 .//file167.txt
#        0 .//file168.txt
#        0 .//file169.txt
#        0 .//file17.txt
#        0 .//file170.txt
#        0 .//file171.txt
#        0 .//file172.txt
#        0 .//file173.txt
#        0 .//file174.txt
#        0 .//file175.txt
#        0 .//file176.txt
#        0 .//file177.txt
#        0 .//file178.txt
#        0 .//file179.txt
#        0 .//file18.txt
#        0 .//file180.txt
#        0 .//file181.txt
#        0 .//file182.txt
#        0 .//file183.txt
#        0 .//file184.txt
#        0 .//file185.txt
#        0 .//file186.txt
#        0 .//file187.txt
#        0 .//file188.txt
#        0 .//file189.txt
#        0 .//file19.txt
#        0 .//file190.txt
#        0 .//file191.txt
#        0 .//file192.txt
#        0 .//file193.txt
#        0 .//file194.txt
#        0 .//file195.txt
#        0 .//file196.txt
#        0 .//file197.txt
#        0 .//file198.txt
#        0 .//file199.txt
#        0 .//file2.txt
#        0 .//file200.txt
#        0 .//file21.txt
#        0 .//file22.txt
#        0 .//file23.txt
#        0 .//file24.txt
#        0 .//file25.txt
#        0 .//file26.txt
#        0 .//file27.txt
#        0 .//file28.txt
#        0 .//file29.txt
#        0 .//file3.txt
#        0 .//file30.txt
#        0 .//file31.txt
#        0 .//file32.txt
#        0 .//file33.txt
#        0 .//file34.txt
#        0 .//file35.txt
#        0 .//file36.txt
#        0 .//file38.txt
#        0 .//file39.txt
#        0 .//file4.txt
#        0 .//file40.txt
#        0 .//file41.txt
#        0 .//file42.txt
#        0 .//file44.txt
#        0 .//file45.txt
#        0 .//file46.txt
#        0 .//file47.txt
#        0 .//file48.txt
#        0 .//file49.txt
#        0 .//file5.txt
#        0 .//file50.txt
#        0 .//file51.txt
#        0 .//file52.txt
#        0 .//file53.txt
#        0 .//file54.txt
#        0 .//file55.txt
#        0 .//file56.txt
#        0 .//file57.txt
#        0 .//file58.txt
#        0 .//file59.txt
#        0 .//file6.txt
#        0 .//file60.txt
#        0 .//file61.txt
#        0 .//file62.txt
#        0 .//file64.txt
#        0 .//file65.txt
#        0 .//file66.txt
#        0 .//file67.txt
#        0 .//file68.txt
#        0 .//file69.txt
#        0 .//file7.txt
#        0 .//file70.txt
#        0 .//file71.txt
#        0 .//file72.txt
#        0 .//file73.txt
#        0 .//file74.txt
#        0 .//file75.txt
#        0 .//file76.txt
#        0 .//file77.txt
#        0 .//file78.txt
#        0 .//file79.txt
#        0 .//file8.txt
#        0 .//file80.txt
#        0 .//file81.txt
#        0 .//file82.txt
#        0 .//file84.txt
#        0 .//file85.txt
#        0 .//file86.txt
#        0 .//file87.txt
#        0 .//file88.txt
#        0 .//file89.txt
#        0 .//file9.txt
#        0 .//file90.txt
#        0 .//file91.txt
#        0 .//file92.txt
#        0 .//file93.txt
#        0 .//file94.txt
#        0 .//file96.txt
#        0 .//file97.txt
#        0 .//file98.txt
#        0 .//file99.txt

# %%
# %%bash
# cd Applied-Bioinformatics-HW
# mkdir HW-test
# cd HW-test
# touch HW
# Out:
# 1.3_jupyter-basics.ipynb
# 1.4_working-with-files.ipynb
# 1.5_redirection-and-pipes.ipynb
# 1.6_awk.ipynb
# 1.7_for_loop_and_string_replacement.ipynb
# 1.8_find_git_stringreplacement_questions.ipynb
# git_reset_local_repo.ipynb
# test-repo
# bash: line 1: cd: Applied-Bioinformatics-HW: No such file or directory

# %%
# %%bash
# cd
# cd Applied-Bioinformatics/Module-1_bash-jupyter-git
# awk 'NR%4==2' data/tmp/simulated1.R1.fq
# Out:
# awk: can't open file data/tmp/simulated1.R1.fq
#  source line number 1
